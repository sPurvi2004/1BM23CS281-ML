# %% [markdown]
# <a href="https://colab.research.google.com/github/sPurvi2004/1BM23CS281-ML/blob/main/data_pre_processing_techniques.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Data Preprocessing Techniques

import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, LabelEncoder

# -------------------------------
# Step 1: Create dataset
# -------------------------------
data = pd.DataFrame({
    'Age': [25, 30, np.nan, 35, 40],
    'Salary': [50000, 60000, 55000, np.nan, 65000],
    'Gender': ['Male', 'Female', 'Female', 'Male', 'Female']
})

print("Original Data:\n", data)

# -------------------------------
# Step 2: Handling Missing Values (FIXED)
# -------------------------------
data['Age'] = data['Age'].fillna(data['Age'].mean())
data['Salary'] = data['Salary'].fillna(data['Salary'].mean())

print("\nAfter Handling Missing Values:\n", data)

# -------------------------------
# Step 3: Encoding Categorical Data
# -------------------------------
le = LabelEncoder()
data['Gender'] = le.fit_transform(data['Gender'])

print("\nAfter Encoding:\n", data)

# -------------------------------
# Step 4: Feature Scaling
# -------------------------------
scaler = StandardScaler()
data[['Age', 'Salary']] = scaler.fit_transform(data[['Age', 'Salary']])

print("\nAfter Feature Scaling:\n", data)
# Out:
# Original Data:
#      Age   Salary  Gender
# 0  25.0  50000.0    Male
# 1  30.0  60000.0  Female
# 2   NaN  55000.0  Female
# 3  35.0      NaN    Male
# 4  40.0  65000.0  Female
#
# After Handling Missing Values:
#      Age   Salary  Gender
# 0  25.0  50000.0    Male
# 1  30.0  60000.0  Female
# 2  32.5  55000.0  Female
# 3  35.0  57500.0    Male
# 4  40.0  65000.0  Female
#
# After Encoding:
#      Age   Salary  Gender
# 0  25.0  50000.0       1
# 1  30.0  60000.0       0
# 2  32.5  55000.0       0
# 3  35.0  57500.0       1
# 4  40.0  65000.0       0
#
# After Feature Scaling:
#     Age  Salary  Gender
# 0 -1.5    -1.5       1
# 1 -0.5     0.5       0
# 2  0.0    -0.5       0
# 3  0.5     0.0       1
# 4  1.5     1.5       0
